# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("techsalerator/end-of-day-pricing-data-germany-techsalerator")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\jorj_\.cache\kagglehub\datasets\techsalerator\end-of-day-pricing-data-germany-techsalerator\versions\1

# %%
import pandas as pd

excel_path = r"c:\Users\jorj_\.cache\kagglehub\datasets\techsalerator\end-of-day-pricing-data-germany-techsalerator\versions\1\End-of-Day Pricing Market Data Germany.xlsx"

df = pd.read_excel(excel_path, engine= 'openpyxl')

df.head()
# Out:
#   EDI_Prices_P04_20230808       Unnamed: 1    Unnamed: 2 Unnamed: 3  \
# 0                     MIC  Pricefilesymbol          Isin   Currency
# 1                    XHEL            ACG1V  FI0009008080        EUR
# 2                    XHEL            ALBAV  FI0009000103        EUR
# 3                    XHEL            ALBBV  FI0009001127        EUR
# 4                    XHEL            EQV1V  FI0009009617        EUR
#
#             Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0            PriceDate       Open       High        Low      Close        Mid
# 1  2023-08-08 00:00:00       4.84        4.9       4.84       4.85          0
# 2  2023-08-08 00:00:00       34.5       34.5       33.9       34.1          0
# 3  2023-08-08 00:00:00       33.5         34       33.5       33.7          0
# 4  2023-08-08 00:00:00      16.54      17.28       16.5       16.9          0
#
#    ...         Unnamed: 19 Unnamed: 20                Unnamed: 21 Unnamed: 22  \
# ...
